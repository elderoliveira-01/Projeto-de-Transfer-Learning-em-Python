# %% [markdown]
# <a href="https://colab.research.google.com/github/elderoliveira-01/Projeto-de-Transfer-Learning-em-Python/blob/main/Detec%C3%A7%C3%A3o_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clonar o repositório Darknet
# !git clone https://github.com/pjreddie/darknet
# Navegar até o diretório darknet
# %cd darknet

# Compilar o Darknet
# !make

# Baixar os pesos pré-treinados
# !wget https://pjreddie.com/media/files/yolov3.weights

# Executar o modelo YOLOv3 para detectar objetos em uma imagem
# !./darknet detect cfg/yolov3.cfg yolov3.weights /content/images.jpg
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5955, done.
# remote: Total 5955 (delta 0), reused 0 (delta 0), pack-reused 5955 (from 1)
# Receiving objects: 100% (5955/5955), 6.37 MiB | 12.80 MiB/s, done.
# Resolving deltas: 100% (3932/3932), done.
# /content/darknet/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# ...

# %%
# Clonar o repositório Darknet
# !git clone https://github.com/pjreddie/darknet
# Navegar até o diretório darknet
# %cd darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5955, done.
# remote: Total 5955 (delta 0), reused 0 (delta 0), pack-reused 5955 (from 1)
# Receiving objects: 100% (5955/5955), 6.37 MiB | 13.57 MiB/s, done.
# Resolving deltas: 100% (3932/3932), done.
# /content/darknet/darknet/darknet

# %%
# Compilar o Darknet
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# ...

# %%
# Baixar os pesos pré-treinados
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2024-12-11 18:52:06--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  37.4MB/s    in 6.2s
#
# 2024-12-11 18:52:13 (37.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# Executar o modelo YOLOv3 para detectar objetos em uma imagem
# !./darknet detect cfg/yolov3.cfg yolov3.weights /content/images.jpg -out /content/predictions
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

# Ler a imagem usando cv2.imread
image = cv2.imread('predictions.jpg')

# Checar se a imagem era carregada com sucesso
if image is not None:
# Chamar cv2_imshow para exibir a imagem
  cv2_imshow(image)
else:
  print("Error: Não foi possível carregar 'predictions.jpg'")
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
